# %%
import pandas as pd
import matplotlib as plt

# %%
#read csv and print dataframe
csv = "Housing.csv"
housing_df = pd.read_csv(csv, engine='python', encoding='latin1')
housing_df.head()
# Out:
#             REGNAME            STNAME           CTYNAME  \
# 0     United States     United States     United States
# 1  Northeast Region  Northeast Region  Northeast Region
# 2    Midwest Region    Midwest Region    Midwest Region
# 3      South Region      South Region      South Region
# 4       West Region       West Region       West Region
#
#    Median House Price 2017  Median House Price 2018  Median House Price 2019  \
# 0                137259144                138391688                139553076
# 1                 24225092                 24329261                 24437166
# 2                 30237036                 30392097                 30536017
# 3                 52836278                 53409488                 54020922
# 4                 29960738                 30260842                 30558971
#
#    Median House Price 042020  Median House Price 2020
# 0                  140471587                140775530
# 1                   24516107                 24542231
# ...

# %%
calhousing_df = pd.DataFrame(housing_df.loc[housing_df["STNAME"]=="California"])
calhousing_df = calhousing_df.drop(columns = ["STNAME"])
calhousing_df.reset_index()
calhousing_df
# Out:
#          REGNAME                 CTYNAME  Median House Price 2017  \
# 196  West Region          Alameda County                   600623
# 197  West Region           Alpine County                     1778
# 198  West Region           Amador County                    18203
# 199  West Region            Butte County                    99177
# 200  West Region        Calaveras County                    27988
# 201  West Region           Colusa County                     8119
# 202  West Region     Contra Costa County                   412936
# 203  West Region        Del Norte County                    11313
# 204  West Region        El Dorado County                    91057
# 205  West Region           Fresno County                   330920
# 206  West Region            Glenn County                    11129
# 207  West Region         Humboldt County                    62776
# 208  West Region         Imperial County                    57558
# ...

# %%
#print dataframe into csv file
calhousing_df.to_csv('housing_df.csv')
