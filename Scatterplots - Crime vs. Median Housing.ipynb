# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as stats
from scipy.stats import linregress

# %%
data_df = pd.read_csv("crime_per_capita_housing_df.csv")

# %%
data_df.head()
# Out:
#    Unnamed: 0     County     2016     2017     2018     2019     2020  \
# 0           0    Alameda  70242.0  74223.0  69248.0  76846.0  68433.0
# 1           1     Alpine     40.0     45.0     41.0     45.0     33.0
# 2           2     Amador    765.0    769.0    721.0    795.0    745.0
# 3           3      Butte   8310.0   8375.0   7120.0   6421.0   5546.0
# 4           4  Calaveras    834.0    998.0   1057.0    983.0    924.0
#
#     Latitude   Longitude  Population 2016  ...  2018 Crime per Capita (%)  \
# 0  37.647138 -121.912488        1650765.0  ...                   4.155056
# 1  38.621783 -119.798352           1053.0  ...                   3.792784
# 2  38.443550 -120.653856          37443.0  ...                   1.832321
# 3  39.665959 -121.601919         226222.0  ...                   3.091217
# 4  38.183900 -120.561442          45307.0  ...                   2.310534
#
#    2019 Crime per Capita (%)  2020 Crime per Capita (%)  2016 Median Housing  \
# ...

# %%
# Build scatter plot for crime vs. median housing price
plt.figure(figsize=(8,5))
plt.scatter(x=data_df["2016 Crime per Capita (%)"], y=data_df["2016 Median Housing"], marker="o", facecolors="blue", edgecolors="black")
plt.xlabel("Crimes Per Capita (%)")
plt.ylabel("Median House Price ($)")
plt.title("Crime vs. Median House Price in California Counties in 2016")
plt.grid()
x_values = data_df.loc[:,"2016 Crime per Capita (%)"]
y_values = data_df.loc[:,"2016 Median Housing"]

#Find slope, y-intercept, r, pvalue, and standard deviation.  Put these values into a linear regression
(slope, intercept, rvalue, pvalue, stdev) = linregress(x_values, y_values)

#Develop linear regression
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept,2))
regress_values = x_values * slope + intercept

#Plot linear regression and rvalue
plt.plot(x_values, regress_values , "r-")
plt.annotate(line_eq, (4,500000), fontsize=12, color="red")
plt.annotate(f"r = {round(rvalue,6)}", (5.05,210000), color="teal")
print(line_eq)

#print r-value
print(f"The r-value is {rvalue}")

# Save the figure
plt.savefig("crime_housing_scatter/CrimevHouse16.png")

# Show plot
plt.show()
# Out:
# y = 9419.37x + 320390.34
# The r-value is 0.04532001106243422

# %%
# Build scatter plot for crime vs. median housing price
plt.figure(figsize=(8,5))
plt.scatter(x=data_df["2017 Crime per Capita (%)"], y=data_df["2017 Median Housing"], marker="o", facecolors="purple", edgecolors="black")
plt.xlabel("Crimes Per Capita (%)")
plt.ylabel("Median House Price ($)")
plt.title("Crime vs. Median House Price in California Counties in 2017")
plt.grid()

x_values = data_df.loc[:,"2017 Crime per Capita (%)"]
y_values = data_df.loc[:,"2017 Median Housing"]

#Find slope, y-intercept, r, pvalue, and standard deviation.  Put these values into a linear regression
(slope, intercept, rvalue, pvalue, stdev) = linregress(x_values, y_values)

#Develop linear regression
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept,2))
regress_values = x_values * slope + intercept

#Plot linear regression and rvalue
plt.plot(x_values, regress_values , "r-")
plt.annotate(line_eq, (4.05,510000), fontsize=12, color="red")
plt.annotate(f"r = {round(rvalue,6)}", (5.05,210000), color="teal")
print(line_eq)

#print r-value
print(f"The r-value is {rvalue}")

# Save the figure
plt.savefig("crime_housing_scatter/CrimevHouse17.png")

# Show plot
plt.show()
# Out:
# y = 21406.52x + 313098.29
# The r-value is 0.09908289937103226

# %%
# Build scatter plot for crime vs. median housing price
plt.figure(figsize=(8,5))
plt.scatter(x=data_df["2018 Crime per Capita (%)"], y=data_df["2018 Median Housing"], marker="o", facecolors="orange", edgecolors="black")
plt.xlabel("Crimes Per Capita (%)")
plt.ylabel("Median House Price (in $1,000,000s)")
plt.title("Crime vs. Median House Price in California Counties in 2018")
plt.grid()

x_values = data_df.loc[:,"2018 Crime per Capita (%)"]
y_values = data_df.loc[:,"2018 Median Housing"]

#Find slope, y-intercept, r, pvalue, and standard deviation.  Put these values into a linear regression
(slope, intercept, rvalue, pvalue, stdev) = linregress(x_values, y_values)

#Develop linear regression
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept,2))
regress_values = x_values * slope + intercept

#Plot linear regression and rvalue
plt.plot(x_values, regress_values , "r-")
plt.annotate(line_eq, (3.5, 600000), fontsize=12, color="red")
plt.annotate(f"r = {round(rvalue,6)}", (5.05,210000), color="teal")
print(line_eq)

#print r-value
print(f"The r-value is {rvalue}")

# Save the figure
plt.savefig("crime_housing_scatter/CrimevHouse18.png")

# Show plot
plt.show()
# Out:
# y = 36032.58x + 306251.48
# The r-value is 0.14314405742042802

# %%
# Build scatter plot for crime vs. median housing price
plt.figure(figsize=(8,5))
plt.scatter(x=data_df["2019 Crime per Capita (%)"], y=data_df["2019 Median Housing"], marker="o", facecolors="green", edgecolors="black")
plt.xlabel("Crimes Per Capita (%)")
plt.ylabel("Median House Price (in $1,000,000s)")
plt.title("Crime vs. Median House Price in California Counties in 2019")
plt.grid()

x_values = data_df.loc[:,"2019 Crime per Capita (%)"]
y_values = data_df.loc[:,"2019 Median Housing"]

#Find slope, y-intercept, r, pvalue, and standard deviation.  Put these values into a linear regression
(slope, intercept, rvalue, pvalue, stdev) = linregress(x_values, y_values)

#Develop linear regression
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept,2))
regress_values = x_values * slope + intercept

#Plot linear regression and rvalue
plt.plot(x_values, regress_values , "r-")
plt.annotate(line_eq, (3.5,820000), fontsize=12, color="red")
plt.annotate(f"r = {round(rvalue,6)}", (5.05,210000), color="teal")
print(line_eq)

#print r-value
print(f"The r-value is {rvalue}")

# Save the figure
plt.savefig("crime_housing_scatter/CrimevHouse19.png")

# Show plot
plt.show()
# Out:
# y = 66768.53x + 259021.63
# The r-value is 0.25779176300341

# %%
# Build scatter plot for crime vs. median housing price
plt.figure(figsize=(8,5))
plt.scatter(x=data_df["2020 Crime per Capita (%)"], y=data_df["2020 Median Housing"], marker="o", facecolors="pink", edgecolors="black")
plt.xlabel("Crimes Per Capita (%)")
plt.ylabel("Median House Price (in $1,000,000s)")
plt.title("Crime vs. Median House Price in California Counties in 2020")
plt.grid()

x_values = data_df.loc[:,"2020 Crime per Capita (%)"]
y_values = data_df.loc[:,"2020 Median Housing"]

#Find slope, y-intercept, r, pvalue, and standard deviation.  Put these values into a linear regression
(slope, intercept, rvalue, pvalue, stdev) = linregress(x_values, y_values)

#Develop linear regression
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept,2))

#Plot linear regression and rvalue
regress_values = x_values * slope + intercept
plt.plot(x_values, regress_values , "r-")
plt.annotate(line_eq, (3,1000000), fontsize=12, color="red")
plt.annotate(f"r = {round(rvalue,6)}", (4.05,210000), color="teal")
print(line_eq)

#print r-value
print(f"The r-value is {rvalue}")

# Save the figure
plt.savefig("crime_housing_scatter/CrimevHouse20.png")

# Show plot
plt.show()
# Out:
# y = 84005.12x + 253485.4
# The r-value is 0.24611539422892773
